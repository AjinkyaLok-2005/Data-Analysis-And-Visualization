# %%
import numpy as np

import pandas as pd

from pandas import Series,DataFrame

# %%
import webbrowser
website = "https://en.wikipedia.org/wiki/NFL_win-loss_records"
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
nfl_frame.Team
# Out:
# 0          Dallas Cowboys
# 1       Green Bay Packers
# 2        Baltimore Ravens
# 3           Chicago Bears
# 4    New England Patriots
# Name: Team, dtype: object

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1920  NFC North
# 4              1960   AFC East

# %%
nfl_frame.loc[3]
# Out:
# Rank                            4
# Team                Chicago Bears
# GP                          1,469
# Won                           793
# Lost                          634
# Tied[c]                    42 (1)
# Pct.                        0.556
# First NFL season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
nfl_frame.head(3)
# Out:
#    Rank               Team     GP  Won  Lost Tied[c]   Pct.  First NFL season  \
# 0     1     Dallas Cowboys    981  562   413   6 (0)  0.576              1960
# 1     2  Green Bay Packers  1,435  799   598  38 (8)  0.572              1921
# 2     3   Baltimore Ravens    451  256   194       1  0.569              1996
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  AFC North

# %%
DataFrame(nfl_frame,cloumns= ["Team","First Season","Total Games","Stadium"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Stadium'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 nfl_frame["Stadium"]
#
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
DataFrame(nfl_frame,columns = ["Team","GP","Won","Stadium"])
# Out:
#                    Team     GP  Won  Stadium
# 0        Dallas Cowboys    981  562      NaN
# 1     Green Bay Packers  1,435  799      NaN
# 2      Baltimore Ravens    451  256      NaN
# 3         Chicago Bears  1,469  793      NaN
# 4  New England Patriots    983  541      NaN

# %%
# nfl_frame["Stadium"] = np.array(["a","b","c","d","e"])

# %%
# nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division Stadium
# 0              1960   NFC East       a
# 1              1921  NFC North       b
# 2              1996  AFC North       c
# 3              1920  NFC North       d
# 4              1960   AFC East       e

# %%
 stad = Series(["s1","s2"],index = [3,1])

# %%
nfl_frame["Stadium"] = stad

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division Stadium Stadiums
# 0              1960   NFC East     NaN      NaN
# 1              1921  NFC North      s2       s2
# 2              1996  AFC North     NaN      NaN
# 3              1920  NFC North      s1       s1
# 4              1960   AFC East     NaN      NaN

# %%
del nfl_frame["Stadiums"]

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost Tied[c]   Pct.  \
# 0     1        Dallas Cowboys    981  562   413   6 (0)  0.576
# 1     2     Green Bay Packers  1,435  799   598  38 (8)  0.572
# 2     3      Baltimore Ravens    451  256   194       1  0.569
# 3     4         Chicago Bears  1,469  793   634  42 (1)  0.556
# 4     5  New England Patriots    983  541   433   9 (0)  0.555
#
#    First NFL season   Division Stadium
# 0              1960   NFC East     NaN
# 1              1921  NFC North      s2
# 2              1996  AFC North     NaN
# 3              1920  NFC North      s1
# 4              1960   AFC East     NaN
